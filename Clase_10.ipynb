# %% [markdown]
# <a href="https://colab.research.google.com/github/GiselaCS/Mujeres_Digitales/blob/main/Clase_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
juan = pd.Series([3, None , 11, 9],\
                     index=['David', 'Pedro', 'Ju', 'Lin'],\
                     name='Counts')

juan2 = pd.Series([5, None , 15, 21],\
                     index=['David', 'Pedro', 'Ju', 'Lin'],\
                     name='Counts')
# Procesos iterativos
for value in juan: 
  print(value)
# Out:
# 3.0
# nan
# 11.0
# 9.0

# %%
# Uso de counts
jj = pd.Series([67.3, 100, 96.7, None, 100],\
               index=['R', 'P', 'G', 'P', 'B'],\
               name='test2')
print(jj)
# Out:
# R     67.3
# P    100.0
# G     96.7
# P      NaN
# B    100.0
# Name: test2, dtype: float64

# %%
print(jj.count())
print('----')
print(jj.value_counts())
print('----')
print(jj.unique())
print('----')
print(jj.drop_duplicates())
print('----')
print(jj.duplicated())
# Out:
# 4
# ----
# 100.0    2
# 96.7     1
# 67.3     1
# Name: test2, dtype: int64
# ----
# [ 67.3 100.   96.7   nan]
# ----
# R     67.3
# P    100.0
# G     96.7
# P      NaN
# Name: test2, dtype: float64
# ----
# R    False
# P    False
# G    False
# P    False
# B     True
# Name: test2, dtype: bool

# %%
print(jj.groupby(jj.index).first())
print('-----------')
print(jj.groupby(jj.index).last())
# Out:
# B    100.0
# G     96.7
# P    100.0
# R     67.3
# Name: test2, dtype: float64
# -----------
# B    100.0
# G     96.7
# P    100.0
# R     67.3
# Name: test2, dtype: float64

# %%
# Funciones estadisticas
print(jj.mean())
print(jj.median())
print(jj.quantile())
print(jj.quantile(0.1))
print(jj.quantile(0.9))
print('------------')
print(jj.describe())
print('-----------')
print(jj.describe(percentiles=[0.05,0.1,0.2]))
print('------------')
print(jj.min())
print('------------')
print(jj.idxmin())
print('------------')
print(jj.max())
print('------------')
print(jj.idxmax())
# Out:
# 91.0
# 98.35
# 98.35
# 76.12
# 100.0
# ------------
# count      4.000000
# mean      91.000000
# std       15.876398
# min       67.300000
# 25%       89.350000
# 50%       98.350000
# 75%      100.000000
# max      100.000000
# Name: test2, dtype: float64
# -----------
# count      4.000000
# mean      91.000000
# std       15.876398
# min       67.300000
# 5%        71.710000
# 10%       76.120000
# 20%       84.940000
# 50%       98.350000
# max      100.000000
# Name: test2, dtype: float64
# ------------
# 67.3
# ------------
# R
# ------------
# 100.0
# ------------
# P

# %%
print('------------')
print(jj.var())
print('------------')
print(jj.std())
print('------------')
print(jj.mad())
print('------------')
print(jj.skew())
print('------------')
print(jj.kurt())
print('------------')
print(jj.corr(juan2))
print('------------')
print(jj.cumsum())
print('------------')
print(jj.cumprod())
jj.hist()
# Out:
# ------------
# 252.06000000000006
# ------------
# 15.876397576276554
# ------------
# 11.850000000000001
# ------------
# -1.9439329105552396
# ------------
# 3.7963553468668323
# ------------
# nan
# ------------
# R     67.3
# P    167.3
# G    264.0
# P      NaN
# B    364.0
# Name: test2, dtype: float64
# ------------
# R          67.3
# P        6730.0
# G      650791.0
# P           NaN
# B    65079100.0
# Name: test2, dtype: float64

# %%
# Lidiar con Nas
print(jj.fillna(-1))
print(jj.dropna())
val_mask = jj.notnull()
val_mask
jj[val_mask]
# Out:
# R     67.3
# P    100.0
# G     96.7
# P     -1.0
# B    100.0
# Name: test2, dtype: float64
# R     67.3
# P    100.0
# G     96.7
# B    100.0
# Name: test2, dtype: float64
# R     67.3
# P    100.0
# G     96.7
# B    100.0
# Name: test2, dtype: float64

# %%
# Sorting
orig = jj.copy()
print(orig.sort_values())
print(orig.sort_values(ascending=False))
print(orig.sort_index())
print(orig.sort_index(ascending=False))
#print(orig.rank())
# Out:
# R     67.3
# G     96.7
# P    100.0
# B    100.0
# P      NaN
# Name: test2, dtype: float64
# B    100.0
# P    100.0
# G     96.7
# R     67.3
# P      NaN
# Name: test2, dtype: float64
# B    100.0
# G     96.7
# P    100.0
# P      NaN
# R     67.3
# Name: test2, dtype: float64
# R     67.3
# P    100.0
# P      NaN
# G     96.7
# B    100.0
# Name: test2, dtype: float64

# %%
# Aplicando funciones
def format(x): 
  if x == 1:
    template = '{} David'
  else:
    template = '{} David'
  return template.format(x)
jj.map(format)
# Out:
# R     67.3 David
# P    100.0 David
# G     96.7 David
# P      nan David
# B    100.0 David
# Name: test2, dtype: object

# %%
# Operaciones con strings
nombres = pd.Series(['Jorge', 'John', 'Paula'])
print(nombres.str.lower())
print(nombres.str.findall('o'))
# Out:
# 0    jorge
# 1     john
# 2    paula
# dtype: object
# 0    [o]
# 1    [o]
# 2     []
# dtype: object

# %%
import numpy as np

data = np.array([['', "col1", "col2","col3","col4"], 
                 ["row1",11,22,33,44],
                 ["row2",55,66,77,88],
                 ["row3",99,1010,1111,1212],
                 ["row4",1313,1414,1515,1616]])

# %%
# data = all data ex = col 0 | columns = row 0 
df = pd.DataFrame(data=data[1:,1:], index=data[1:,0], columns=data[0,1:])

# %%
print(df)
print(df.shape) # Forma
df['col1']['row1'] # coordenadas
# Out:
#       col1  col2  col3  col4
# row1    11    22    33    44
# row2    55    66    77    88
# row3    99  1010  1111  1212
# row4  1313  1414  1515  1616
# (4, 4)
# '11'

# %%
for indx in range(4):
  print(df.iloc[indx,indx])
# Out:
# 11
# 66
# 1111
# 1616

# %% [markdown]
# es lo mismo que hacer

# %%
print(df.iloc[0,0])
print(df.iloc[1,1])
print(df.iloc[2,2])
print(df.iloc[3,3])
# Out:
# 11
# 66
# 1111
# 1616

# %%
#otra forma con iloc
indices = df.index.to_list() #convertir todas las filas a lista
columnas = df.columns.to_list() #convertir todas las columnas a lista
print(indices, columnas)
# Out:
# ['row1', 'row2', 'row3', 'row4'] ['col1', 'col2', 'col3', 'col4']

# %%
for indx in range(4):
  print(df.iloc[indx,indx])
# Out:
# 11
# 66
# 1111
# 1616

# %%
#otra forma de hacerlo el llamado completo
for j in range(4): #filas
  for m in range(4): #columnas
    if j<=m:
      print( df.iloc[j,m])
# Out:
# 11
# 22
# 33
# 44
# 66
# 77
# 88
# 1111
# 1212
# 1616

# %%
#otra forma de hacerlo
for x in range(4):
  print(df.iloc[x,x:]) #las columnas se recorren hasta el final
# Out:
# col1    11
# col2    22
# col3    33
# col4    44
# Name: row1, dtype: object
# col2    66
# col3    77
# col4    88
# Name: row2, dtype: object
# col3    1111
# col4    1212
# Name: row3, dtype: object
# col4    1616
# Name: row4, dtype: object

# %%
for ind in df.index: #indice
  for col in df.columns: #columna
    df.loc[ind,col] #indice 1 columna 1

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-5a6fd806-acc9-440a-ab98-d0a43a91ceb1" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5a6fd806-acc9-440a-ab98-d0a43a91ceb1">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving pokemon_data.csv to pokemon_data (1).csv

# %%
import os
print(os.getcwd())
# Out:
# /content

# %%
pk = pd.read_csv('pokemon_data.csv')

# %%
pk.head()
# Out:
#    #                   Name Type 1  ... Speed  Generation  Legendary
# 0  1              Bulbasaur  Grass  ...    45           1      False
# 1  2                Ivysaur  Grass  ...    60           1      False
# 2  3               Venusaur  Grass  ...    80           1      False
# 3  3  VenusaurMega Venusaur  Grass  ...    80           1      False
# 4  4             Charmander   Fire  ...    65           1      False
#
# [5 rows x 12 columns]

# %%
pk_type =pk['Type 1'].unique()

# %%
pk['catched'] = False

# %%
pk.head()
# Out:
#    #                   Name Type 1  ... Generation  Legendary  catched
# 0  1              Bulbasaur  Grass  ...          1      False    False
# 1  2                Ivysaur  Grass  ...          1      False    False
# 2  3               Venusaur  Grass  ...          1      False    False
# 3  3  VenusaurMega Venusaur  Grass  ...          1      False    False
# 4  4             Charmander   Fire  ...          1      False    False
#
# [5 rows x 13 columns]

# %%
#todos
pk
# Out:
#        #                   Name   Type 1  ... Generation  Legendary  catched
# 0      1              Bulbasaur    Grass  ...          1      False    False
# 1      2                Ivysaur    Grass  ...          1      False    False
# 2      3               Venusaur    Grass  ...          1      False    False
# 3      3  VenusaurMega Venusaur    Grass  ...          1      False    False
# 4      4             Charmander     Fire  ...          1      False    False
# ..   ...                    ...      ...  ...        ...        ...      ...
# 795  719                Diancie     Rock  ...          6       True    False
# 796  719    DiancieMega Diancie     Rock  ...          6       True    False
# 797  720    HoopaHoopa Confined  Psychic  ...          6       True    False
# 798  720     HoopaHoopa Unbound  Psychic  ...          6       True    False
# 799  721              Volcanion     Fire  ...          6       True    False
#
# [800 rows x 13 columns]

# %%
#pk[pk['Type 1']== 'Grass'].loc[:,'catched'] = True
mask= pk['Type 1'] == 'Grass'

mask
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Name: Type 1, Length: 800, dtype: bool

# %%
pk.loc[mask, 'catched']= True #mask es las filas y catched las columnas
pk.head()
# Out:
#    #                   Name Type 1  ... Generation  Legendary  catched
# 0  1              Bulbasaur  Grass  ...          1      False     True
# 1  2                Ivysaur  Grass  ...          1      False     True
# 2  3               Venusaur  Grass  ...          1      False     True
# 3  3  VenusaurMega Venusaur  Grass  ...          1      False     True
# 4  4             Charmander   Fire  ...          1      False    False
#
# [5 rows x 13 columns]

# %%
pk.head(10)
# Out:
#    #                       Name Type 1  ... Generation  Legendary  catched
# 0  1                  Bulbasaur  Grass  ...          1      False    False
# 1  2                    Ivysaur  Grass  ...          1      False    False
# 2  3                   Venusaur  Grass  ...          1      False    False
# 3  3      VenusaurMega Venusaur  Grass  ...          1      False    False
# 4  4                 Charmander   Fire  ...          1      False    False
# 5  5                 Charmeleon   Fire  ...          1      False    False
# 6  6                  Charizard   Fire  ...          1      False    False
# 7  6  CharizardMega Charizard X   Fire  ...          1      False    False
# 8  6  CharizardMega Charizard Y   Fire  ...          1      False    False
# 9  7                   Squirtle  Water  ...          1      False    False
#
# [10 rows x 13 columns]

# %%
#tipos de pokemones
for i in pk_type:
  print(i)
# Out:
# Grass
# Fire
# Water
# Bug
# Normal
# Poison
# Electric
# Ground
# Fairy
# Fighting
# Psychic
# Rock
# Ghost
# Ice
# Dragon
# Dark
# Steel
# Flying

# %%
mask1= pk['Type 1']== 'Fire'
mask1
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4       True
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799     True
# Name: Type 1, Length: 800, dtype: bool

# %%
pk.loc[mask1, 'catched']= True #mask es las filas y catched las columnas
pk.head()
# Out:
#    #                   Name Type 1  ... Generation  Legendary  catched
# 0  1              Bulbasaur  Grass  ...          1      False     True
# 1  2                Ivysaur  Grass  ...          1      False     True
# 2  3               Venusaur  Grass  ...          1      False     True
# 3  3  VenusaurMega Venusaur  Grass  ...          1      False     True
# 4  4             Charmander   Fire  ...          1      False     True
#
# [5 rows x 13 columns]

# %%
mask2=pk['Type 1']== 'Water'
mask2
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Name: Type 1, Length: 800, dtype: bool

# %%
pk.loc[mask2, 'catched']= True #mask es las filas y catched las columnas
pk.head()
# Out:
#    #                   Name Type 1  ... Generation  Legendary  catched
# 0  1              Bulbasaur  Grass  ...          1      False     True
# 1  2                Ivysaur  Grass  ...          1      False     True
# 2  3               Venusaur  Grass  ...          1      False     True
# 3  3  VenusaurMega Venusaur  Grass  ...          1      False     True
# 4  4             Charmander   Fire  ...          1      False     True
#
# [5 rows x 13 columns]

# %%
pk_type =pk['Type 2'].unique()

# %%
#pokemones legendarios
mask3=pk['Type 2'] == 'Fire'
mask3
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Name: Type 2, Length: 800, dtype: bool

# %%
pk.loc[mask3, 'Legendary']= True #mask es las filas y catched las columnas
pk.head(10)
# Out:
#    #                       Name Type 1  ... Legendary  catched  legendary
# 0  1                  Bulbasaur  Grass  ...     False     True        NaN
# 1  2                    Ivysaur  Grass  ...     False     True        NaN
# 2  3                   Venusaur  Grass  ...     False     True        NaN
# 3  3      VenusaurMega Venusaur  Grass  ...     False     True        NaN
# 4  4                 Charmander   Fire  ...      True     True       True
# 5  5                 Charmeleon   Fire  ...      True     True       True
# 6  6                  Charizard   Fire  ...      True     True       True
# 7  6  CharizardMega Charizard X   Fire  ...      True     True       True
# 8  6  CharizardMega Charizard Y   Fire  ...      True     True       True
# 9  7                   Squirtle  Water  ...     False     True        NaN
#
# [10 rows x 14 columns]

# %%
#pokemones con HP mayor o igual a 50
pk[pk['HP']>=50]
# Out:
#        #                   Name   Type 1  ... Generation  Legendary  catched
# 1      2                Ivysaur    Grass  ...          1      False    False
# 2      3               Venusaur    Grass  ...          1      False    False
# 3      3  VenusaurMega Venusaur    Grass  ...          1      False    False
# 5      5             Charmeleon     Fire  ...          1      False    False
# 6      6              Charizard     Fire  ...          1      False    False
# ..   ...                    ...      ...  ...        ...        ...      ...
# 795  719                Diancie     Rock  ...          6      False    False
# 796  719    DiancieMega Diancie     Rock  ...          6      False    False
# 797  720    HoopaHoopa Confined  Psychic  ...          6      False    False
# 798  720     HoopaHoopa Unbound  Psychic  ...          6      False    False
# 799  721              Volcanion     Fire  ...          6      False    False
#
# [652 rows x 13 columns]

# %%
#pokemones con HP menos  o igual a 50
pk[pk['HP']<=50]
# Out:
#        #                   Name  Type 1  ... Generation  Legendary  catched
# 0      1              Bulbasaur   Grass  ...          1      False    False
# 4      4             Charmander    Fire  ...          1      False    False
# 9      7               Squirtle   Water  ...          1      False    False
# 13    10               Caterpie     Bug  ...          1      False    False
# 14    11                Metapod     Bug  ...          1      False    False
# ..   ...                    ...     ...  ...        ...        ...      ...
# 780  710  PumpkabooAverage Size   Ghost  ...          6      False    False
# 781  710    PumpkabooSmall Size   Ghost  ...          6      False    False
# 790  714                 Noibat  Flying  ...          6      False    False
# 795  719                Diancie    Rock  ...          6      False    False
# 796  719    DiancieMega Diancie    Rock  ...          6      False    False
#
# [211 rows x 13 columns]

# %%
#pokemones con Ataque mayor o igual a 50
pk[pk['Attack']>=50]
# Out:
#        #                   Name   Type 1  ... Generation  Legendary  catched
# 1      2                Ivysaur    Grass  ...          1      False    False
# 2      3               Venusaur    Grass  ...          1      False    False
# 3      3  VenusaurMega Venusaur    Grass  ...          1      False    False
# 4      4             Charmander     Fire  ...          1      False    False
# 5      5             Charmeleon     Fire  ...          1      False    False
# ..   ...                    ...      ...  ...        ...        ...      ...
# 795  719                Diancie     Rock  ...          6      False    False
# 796  719    DiancieMega Diancie     Rock  ...          6      False    False
# 797  720    HoopaHoopa Confined  Psychic  ...          6      False    False
# 798  720     HoopaHoopa Unbound  Psychic  ...          6      False    False
# 799  721              Volcanion     Fire  ...          6      False    False
#
# [667 rows x 13 columns]

# %%
#pokemones con ataque menor o igual a 50
pk[pk['Attack']<=50]
# Out:
#        #        Name    Type 1  Type 2  ...  Speed  Generation  Legendary  catched
# 0      1   Bulbasaur     Grass  Poison  ...     45           1      False    False
# 9      7    Squirtle     Water     NaN  ...     43           1      False    False
# 13    10    Caterpie       Bug     NaN  ...     45           1      False    False
# 14    11     Metapod       Bug     NaN  ...     30           1      False    False
# 15    12  Butterfree       Bug  Flying  ...     70           1      False    False
# ..   ...         ...       ...     ...  ...    ...         ...        ...      ...
# 754  684     Swirlix     Fairy     NaN  ...     49           6      False    False
# 764  694  Helioptile  Electric  Normal  ...     70           6      False    False
# 773  703     Carbink      Rock   Fairy  ...     50           6      False    False
# 774  704       Goomy    Dragon     NaN  ...     40           6      False    False
# ...

# %%
#pokemones con Defensa mayor o igual a 50
pk[pk['Defense']>=50]
# Out:
#        #                   Name   Type 1  ... Generation  Legendary  catched
# 1      2                Ivysaur    Grass  ...          1      False    False
# 2      3               Venusaur    Grass  ...          1      False    False
# 3      3  VenusaurMega Venusaur    Grass  ...          1      False    False
# 5      5             Charmeleon     Fire  ...          1      False    False
# 6      6              Charizard     Fire  ...          1      False    False
# ..   ...                    ...      ...  ...        ...        ...      ...
# 795  719                Diancie     Rock  ...          6      False    False
# 796  719    DiancieMega Diancie     Rock  ...          6      False    False
# 797  720    HoopaHoopa Confined  Psychic  ...          6      False    False
# 798  720     HoopaHoopa Unbound  Psychic  ...          6      False    False
# 799  721              Volcanion     Fire  ...          6      False    False
#
# [637 rows x 13 columns]

# %%
#pokemones con Defensa menor o igual a 50
pk[pk['Defense']<=50]
# Out:
#        #        Name    Type 1  Type 2  ...  Speed  Generation  Legendary  catched
# 0      1   Bulbasaur     Grass  Poison  ...     45           1      False    False
# 4      4  Charmander      Fire     NaN  ...     65           1      False    False
# 13    10    Caterpie       Bug     NaN  ...     45           1      False    False
# 15    12  Butterfree       Bug  Flying  ...     70           1      False    False
# 16    13      Weedle       Bug  Poison  ...     50           1      False    False
# ..   ...         ...       ...     ...  ...    ...         ...        ...      ...
# 764  694  Helioptile  Electric  Normal  ...     70           6      False    False
# 768  698      Amaura      Rock     Ice  ...     46           6      False    False
# 774  704       Goomy    Dragon     NaN  ...     40           6      False    False
# 778  708    Phantump     Ghost   Grass  ...     38           6      False    False
# ...

# %%
pk['Type 2'].unique()
# Out:
# array(['Poison', nan, 'Flying', 'Dragon', 'Ground', 'Fairy', 'Grass',
#        'Fighting', 'Psychic', 'Steel', 'Ice', 'Rock', 'Dark', 'Water',
#        'Electric', 'Fire', 'Ghost', 'Bug', 'Normal'], dtype=object)

# %%
for i in pk_type:
  print(i)
# Out:
# Poison
# nan
# Flying
# Dragon
# Ground
# Fairy
# Grass
# Fighting
# Psychic
# Steel
# Ice
# Rock
# Dark
# Water
# Electric
# Fire
# Ghost
# Bug
# Normal

# %%
pk_hp= pk['HP'].unique()

# %%
for i in pk_hp:
  print(i)
# Out:
# 45
# 60
# 80
# 39
# 58
# 78
# 44
# 59
# 79
# 50
# 40
# 65
# 63
# 83
# 30
# 55
# 35
# 75
# 70
# 90
# 46
# 61
# 81
# 95
# 38
# 73
# 115
# 140
# 10
# 25
# 52
# 105
# 85
# 250
# 20
# 130
# 48
# 160
# 41
# 91
# 106
# 100
# 125
# 190
# 255
# 28
# 68
# 150
# 31
# 1
# 64
# 84
# 104
# 72
# 144
# 170
# 110
# 43
# 66
# 86
# 99
# 76
# 53
# 37
# 77
# 67
# 97
# 111
# 49
# 71
# 103
# 57
# 108
# 135
# 74
# 69
# 120
# 116
# 62
# 54
# 36
# 51
# 114
# 165
# 109
# 89
# 92
# 56
# 88
# 123
# 101
# 82
# 42
# 126

# %%
#atrapar a todos los pokemones
pk['catched'] = True

# %%
pk.head()
# Out:
#    #                   Name Type 1  ... Legendary  catched  legendary
# 0  1              Bulbasaur  Grass  ...     False     True        NaN
# 1  2                Ivysaur  Grass  ...     False     True        NaN
# 2  3               Venusaur  Grass  ...     False     True        NaN
# 3  3  VenusaurMega Venusaur  Grass  ...     False     True        NaN
# 4  4             Charmander   Fire  ...      True     True       True
#
# [5 rows x 14 columns]

# %%
# con loc podemos traer los valores que queramos y elegir rangos para cambiar valores
pk.loc[0:3, 'catched'] = False

# %%
pk.head(6)
# Out:
#    #                   Name Type 1  ... Legendary  catched  legendary
# 0  1              Bulbasaur  Grass  ...     False    False        NaN
# 1  2                Ivysaur  Grass  ...     False    False        NaN
# 2  3               Venusaur  Grass  ...     False    False        NaN
# 3  3  VenusaurMega Venusaur  Grass  ...     False    False        NaN
# 4  4             Charmander   Fire  ...      True     True       True
# 5  5             Charmeleon   Fire  ...      True     True       True
#
# [6 rows x 14 columns]

# %%
#filtrar
pk.loc[pk['Type 1'] == 'Fire',:] #los dos puntos significa todos los de fuego
# Out:
#        #                       Name Type 1  ... Legendary  catched  legendary
# 4      4                 Charmander   Fire  ...      True     True       True
# 5      5                 Charmeleon   Fire  ...      True     True       True
# 6      6                  Charizard   Fire  ...      True     True       True
# 7      6  CharizardMega Charizard X   Fire  ...      True     True       True
# 8      6  CharizardMega Charizard Y   Fire  ...      True     True       True
# 42    37                     Vulpix   Fire  ...      True     True       True
# 43    38                  Ninetales   Fire  ...      True     True       True
# 63    58                  Growlithe   Fire  ...      True     True       True
# 64    59                   Arcanine   Fire  ...      True     True       True
# 83    77                     Ponyta   Fire  ...      True     True       True
# 84    78                   Rapidash   Fire  ...      True     True       True
# ...

# %%
#filtrar
pk.loc[pk['Type 1'] == 'Rock',:]
# Out:
#        #                       Name Type 1  ... Legendary  catched  legendary
# 80    74                    Geodude   Rock  ...     False     True        NaN
# 81    75                   Graveler   Rock  ...     False     True        NaN
# 82    76                      Golem   Rock  ...     False     True        NaN
# 103   95                       Onix   Rock  ...     False     True        NaN
# 149  138                    Omanyte   Rock  ...     False     True        NaN
# 150  139                    Omastar   Rock  ...     False     True        NaN
# 151  140                     Kabuto   Rock  ...     False     True        NaN
# 152  141                   Kabutops   Rock  ...     False     True        NaN
# 153  142                 Aerodactyl   Rock  ...     False     True        NaN
# 154  142  AerodactylMega Aerodactyl   Rock  ...     False     True        NaN
# 200  185                  Sudowoodo   Rock  ...     False     True        NaN
# ...

# %%
#para borrar columnas se hace con Drop 
#pk.drop(labels="aqui el nombre de la columna", axis=1, implace=True)
#al decirle implece se indica hacer el cambio en el mismo dataFrame
#drop= a este data frame borrele lo siguiente
#label es lo que quiero borrar
#axis es columna o fila = 0 es fila y 1 es columna

# %%
#traer los pokemos si son de fuego o si son tipo grass
pk.loc[(pk['Type 1']== 'Fire') | (pk['Type 1'] == 'Grass'), :]
# Out:
#        #                   Name Type 1  ... Legendary  catched  legendary
# 0      1              Bulbasaur  Grass  ...     False    False        NaN
# 1      2                Ivysaur  Grass  ...     False    False        NaN
# 2      3               Venusaur  Grass  ...     False    False        NaN
# 3      3  VenusaurMega Venusaur  Grass  ...     False    False        NaN
# 4      4             Charmander   Fire  ...      True     True       True
# ..   ...                    ...    ...  ...       ...      ...        ...
# 735  667                 Litleo   Fire  ...      True     True       True
# 736  668                 Pyroar   Fire  ...      True     True       True
# 740  672                 Skiddo  Grass  ...     False     True        NaN
# 741  673                 Gogoat  Grass  ...     False     True        NaN
# 799  721              Volcanion   Fire  ...      True     True       True
#
# [122 rows x 14 columns]

# %% [markdown]
# ejercico

# %%
pk_type= pk['Type 1'].unique()
pk_type
# Out:
# array(['Grass', 'Fire', 'Water', 'Bug', 'Normal', 'Poison', 'Electric',
#        'Ground', 'Fairy', 'Fighting', 'Psychic', 'Rock', 'Ghost', 'Ice',
#        'Dragon', 'Dark', 'Steel', 'Flying'], dtype=object)

# %%
pk['catched']= False

# %%
pk.head(10)
# Out:
#    #                       Name Type 1  ... Legendary  catched  legendary
# 0  1                  Bulbasaur  Grass  ...     False    False        NaN
# 1  2                    Ivysaur  Grass  ...     False    False        NaN
# 2  3                   Venusaur  Grass  ...     False    False        NaN
# 3  3      VenusaurMega Venusaur  Grass  ...     False    False        NaN
# 4  4                 Charmander   Fire  ...      True    False       True
# 5  5                 Charmeleon   Fire  ...      True    False       True
# 6  6                  Charizard   Fire  ...      True    False       True
# 7  6  CharizardMega Charizard X   Fire  ...      True    False       True
# 8  6  CharizardMega Charizard Y   Fire  ...      True    False       True
# 9  7                   Squirtle  Water  ...     False    False        NaN
#
# [10 rows x 14 columns]

# %%
pk.loc[pk['Type 1']== 'Grass', 'catched']= True
pk.head()
# Out:
#    #                   Name Type 1  ... Legendary  catched  legendary
# 0  1              Bulbasaur  Grass  ...     False     True        NaN
# 1  2                Ivysaur  Grass  ...     False     True        NaN
# 2  3               Venusaur  Grass  ...     False     True        NaN
# 3  3  VenusaurMega Venusaur  Grass  ...     False     True        NaN
# 4  4             Charmander   Fire  ...      True    False       True
#
# [5 rows x 14 columns]

# %%
pk.head()
# Out:
#    #                   Name Type 1  ... Legendary  catched  legendary
# 0  1              Bulbasaur  Grass  ...     False     True        NaN
# 1  2                Ivysaur  Grass  ...     False     True        NaN
# 2  3               Venusaur  Grass  ...     False     True        NaN
# 3  3  VenusaurMega Venusaur  Grass  ...     False     True        NaN
# 4  4             Charmander   Fire  ...      True     True       True
#
# [5 rows x 14 columns]

# %%
# Out:
# Flying
#    #                   Name Type 1  ... Legendary  catched  legendary
# 0  1              Bulbasaur  Grass  ...     False     True        NaN
# 1  2                Ivysaur  Grass  ...     False     True        NaN
# 2  3               Venusaur  Grass  ...     False     True        NaN
# 3  3  VenusaurMega Venusaur  Grass  ...     False     True        NaN
# 4  4             Charmander   Fire  ...      True     True       True
#
# [5 rows x 14 columns]

# %%
#automatizar esto
#recorrer cada tipo
for i in pk_type:
  print(i)
  #recorre cada tipo y lo convierte a verdadero
  pk.loc[pk['Type 1']==i, 'catched' ]= True
  # es decir, entrar al tipo uno y cambiarlo a True, y asi con cada tipo
# Out:
# Grass
# Fire
# Water
# Bug
# Normal
# Poison
# Electric
# Ground
# Fairy
# Fighting
# Psychic
# Rock
# Ghost
# Ice
# Dragon
# Dark
# Steel
# Flying

# %%
#trae absolutamente todos los valores completos
pk.describe(include='all')
# Out:
#                  #    Name Type 1  ... Legendary  catched  legendary
# count   800.000000     800    800  ...       800      800         52
# unique         NaN     800     18  ...         2        1          1
# top            NaN  Spoink  Water  ...     False     True       True
# freq           NaN       1    112  ...       679      800         52
# mean    362.813750     NaN    NaN  ...       NaN      NaN        NaN
# std     208.343798     NaN    NaN  ...       NaN      NaN        NaN
# min       1.000000     NaN    NaN  ...       NaN      NaN        NaN
# 25%     184.750000     NaN    NaN  ...       NaN      NaN        NaN
# 50%     364.500000     NaN    NaN  ...       NaN      NaN        NaN
# 75%     539.250000     NaN    NaN  ...       NaN      NaN        NaN
# max     721.000000     NaN    NaN  ...       NaN      NaN        NaN
#
# [11 rows x 14 columns]

# %% [markdown]
# **clase 12, 20 de agosto**

# %%
pk
# Out:
#        #                   Name   Type 1  ... Speed  Generation  Legendary
# 0      1              Bulbasaur    Grass  ...    45           1      False
# 1      2                Ivysaur    Grass  ...    60           1      False
# 2      3               Venusaur    Grass  ...    80           1      False
# 3      3  VenusaurMega Venusaur    Grass  ...    80           1      False
# 4      4             Charmander     Fire  ...    65           1      False
# ..   ...                    ...      ...  ...   ...         ...        ...
# 795  719                Diancie     Rock  ...    50           6       True
# 796  719    DiancieMega Diancie     Rock  ...   110           6       True
# 797  720    HoopaHoopa Confined  Psychic  ...    70           6       True
# 798  720     HoopaHoopa Unbound  Psychic  ...    80           6       True
# 799  721              Volcanion     Fire  ...    70           6       True
#
# [800 rows x 12 columns]

# %%
#agrupar 
pk.groupby(['Type 1']).count()
# Out:
#             #  Name  Type 2   HP  ...  Sp. Def  Speed  Generation  Legendary
# Type 1                            ...
# Bug        69    69      52   69  ...       69     69          69         69
# Dark       31    31      21   31  ...       31     31          31         31
# Dragon     32    32      21   32  ...       32     32          32         32
# Electric   44    44      17   44  ...       44     44          44         44
# Fairy      17    17       2   17  ...       17     17          17         17
# Fighting   27    27       7   27  ...       27     27          27         27
# Fire       52    52      24   52  ...       52     52          52         52
# Flying      4     4       2    4  ...        4      4           4          4
# Ghost      32    32      22   32  ...       32     32          32         32
# Grass      70    70      37   70  ...       70     70          70         70
# Ground     32    32      19   32  ...       32     32          32         32
# ...

# %% [markdown]
# Pandas: crea una hoja de calculo, donde se cargan los datos, cada uno tiene su propias columnas y cada fila tiene su conjunto de datos.
#
# 1. se puede filtrar para escoger los datos por caracteristicas.
# 2. manipular datos
